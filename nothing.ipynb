# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaimLimbu/classes/blob/main/nothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')
data.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
data.tail()
# Out:
#     Experience Years  Salary
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
data.isnull()
data.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
data.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
data.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
x=data[['Experience Years']]
y=data['Salary']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2,random_state=2529)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pridict=model.predict(x_test)
r2=r2_score(y_test,y_pridict)
mse=mean_squared_error(y_test,y_pridict)
print (r2)
print (mse)
# Out:
# 0.9473428596303923
# 36258819.052491635

# %%
Expirence=float(input("Enter your expirence:"))
user_data=pd.DataFrame({'Experience Years':[Expirence]})
prediction=model.predict(user_data)
print(prediction)
# Out:
# Enter your expirence:0
# [23099.51733659]
