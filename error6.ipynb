# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaimLimbu/classes/blob/main/error6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import confusion_matrix, r2_score, mean_absolute_error, precision_score
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("tesla.csv")
data.head()
# Out:
#          Date     Close      High       Low      Open     Volume
# 0  2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1  2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2  2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3  2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4  2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
data.shape
# Out:
# (3765, 6)

# %%
data.isnull().sum()
# Out:
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
data.sample(5)
# Out:
#             Date       Close        High         Low        Open     Volume
# 301   2011-09-07    1.589333    1.600000    1.552000    1.559333    6888000
# 3375  2023-11-24  235.449997  238.750000  232.330002  233.750000   65125200
# 1690  2017-03-16   17.469999   17.716667   17.270666   17.493334  106983000
# 1744  2017-06-02   22.656668   22.858667   22.395332   22.651333   83853000
# 2523  2020-07-08   91.058670   94.484001   87.422668   93.666664  244669500

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3760    False
# 3761    False
# 3762    False
# 3763    False
# 3764    False
# Length: 3765, dtype: bool

# %%
data.columns
# Out:
# Index(['Date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
data.describe()
# Out:
#              Close         High          Low         Open        Volume
# count  3765.000000  3765.000000  3765.000000  3765.000000  3.765000e+03
# mean     88.567852    90.581117    86.465378    88.593070  9.707503e+07
# std     113.754319   116.450259   110.987632   113.848771  7.689793e+07
# min       1.053333     1.108667     0.998667     1.076000  1.777500e+06
# 25%      12.506000    12.764667    12.183333    12.446667  5.014650e+07
# 50%      18.807333    19.118668    18.466667    18.799999  8.319150e+07
# 75%     191.300003   196.360001   186.339996   191.456665  1.225740e+08
# max     479.859985   488.540009   457.510010   475.899994  9.140820e+08

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3765 entries, 0 to 3764
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3765 non-null   object
#  1   Close   3765 non-null   float64
#  2   High    3765 non-null   float64
#  3   Low     3765 non-null   float64
#  4   Open    3765 non-null   float64
#  5   Volume  3765 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 176.6+ KB

# %%
data.shape
# Out:
# (3765, 6)

# %%
data1=data.drop(columns=['Date'])

# %%
x=data1.drop('Volume',axis=1)
y=data1['Volume']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
model=RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
print (r2)
print (mae)
# Out:
# 0.2899101438264158
# 40718636.25498008

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
r3=r2_score(y_test,y_pred)
ma_e=mean_absolute_error(y_test,y_pred)
print (r3)
print (ma_e)
# Out:
# 0.2899101438264158
# 40718636.25498008

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r_2=r2_score(y_test,y_pred)
m_ae=mean_absolute_error(y_test,y_pred)
print (r_2)
print (m_ae)
# Out:
# 0.2899101438264158
# 40718636.25498008
