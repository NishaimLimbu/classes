# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaimLimbu/classes/blob/main/customer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('Customer.csv')
data.head()
# Out:
#   CustomerID  Tenure  MonthlyCharge  TotalCharges        Contract  \
# 0     CUST_1      38     128.570307   4885.671652  Month-to-month
# 1     CUST_2      44     122.904332   5407.790597        One year
# 2     CUST_3      13      79.127233   1028.654035  Month-to-month
# 3     CUST_4       9      88.537223    796.835005  Month-to-month
# 4     CUST_5      10     148.100000   1481.000003        One year
#
#       PaymentMethod  PaperlessBilling  AverageUsage   TotalUsage  Churn
# 0       Credit card                 0     34.577658  1313.950991      0
# 1     Bank transfer                 0     43.387375  1909.044500      0
# 2       Credit card                 0     14.974818   194.672633      0
# 3  Electronic check                 0     14.611459   131.503133      1
# 4  Electronic check                 1     15.346697   153.466972      0

# %%
data.tail()
# Out:
#       CustomerID  Tenure  MonthlyCharge  TotalCharges        Contract  \
# 9995   CUST_9996      54      86.834131   4689.043054        Two year
# 9996   CUST_9997      20      51.204612   1024.092247        Two year
# 9997   CUST_9998      22      48.340459   1063.490087  Month-to-month
# 9998   CUST_9999       9     148.897863   1340.080764        Two year
# 9999  CUST_10000      10     107.038664   1070.386637  Month-to-month
#
#          PaymentMethod  PaperlessBilling  AverageUsage   TotalUsage  Churn
# 9995       Credit card                 1     35.401774  1911.695795      0
# 9996      Mailed check                 0     19.706219   394.124371      0
# 9997      Mailed check                 1      7.017917   154.394178      1
# 9998  Electronic check                 1     16.503422   148.530796      0
# 9999     Bank transfer                 1     21.749402   217.494021      0

# %%
data.sample(5)
# Out:
#      CustomerID  Tenure  MonthlyCharge  TotalCharges        Contract  \
# 1059  CUST_1060      59     138.517255   8172.518022        Two year
# 3820  CUST_3821      24     118.025230   2832.605512        Two year
# 7946  CUST_7947      54      35.451777   1914.395958  Month-to-month
# 7685  CUST_7686      53     107.610471   5703.354967        Two year
# 3933  CUST_3934       4      23.303104     93.212416        One year
#
#          PaymentMethod  PaperlessBilling  AverageUsage   TotalUsage  Churn
# 1059     Bank transfer                 1     37.123250  2190.271772      1
# 3820  Electronic check                 0     21.711888   521.085309      0
# 7946       Credit card                 1     28.709776  1550.327925      0
# 7685       Credit card                 1     27.931294  1480.358590      1
# 3933       Credit card                 0     -3.698552   -14.794209      0

# %%
data.describe()
# Out:
#              Tenure  MonthlyCharge  TotalCharges  PaperlessBilling  \
# count  10000.000000   10000.000000  10000.000000      10000.000000
# mean      30.400400      85.084025   2585.529299          0.490400
# std       17.342409      37.513394   1962.580650          0.499933
# min        1.000000      20.006127     20.605553          0.000000
# 25%       15.000000      52.482154    993.730563          0.000000
# 50%       30.000000      85.601102   2091.346192          0.000000
# 75%       45.000000     117.516909   3830.800072          1.000000
# max       60.000000     149.967994   8953.491483          1.000000
#
#        AverageUsage    TotalUsage         Churn
# count  10000.000000  10000.000000  10000.000000
# mean      23.773643    875.043449      0.244600
# std       10.734317    725.468700      0.429871
# min       -8.216199    -83.609255      0.000000
# 25%       15.684474    232.703263      0.000000
# 50%       23.778875    696.955976      0.000000
# ...

# %%
data.columns
# Out:
# Index(['CustomerID', 'Tenure', 'MonthlyCharge', 'TotalCharges', 'Contract',
#        'PaymentMethod', 'PaperlessBilling', 'AverageUsage', 'TotalUsage',
#        'Churn'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
data.isnull()
# Out:
#       CustomerID  Tenure  MonthlyCharge  TotalCharges  Contract  \
# 0          False   False          False         False     False
# 1          False   False          False         False     False
# 2          False   False          False         False     False
# 3          False   False          False         False     False
# 4          False   False          False         False     False
# ...          ...     ...            ...           ...       ...
# 9995       False   False          False         False     False
# 9996       False   False          False         False     False
# 9997       False   False          False         False     False
# 9998       False   False          False         False     False
# 9999       False   False          False         False     False
#
#       PaymentMethod  PaperlessBilling  AverageUsage  TotalUsage  Churn
# 0             False             False         False       False  False
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID          0
# Tenure              0
# MonthlyCharge       0
# TotalCharges        0
# Contract            0
# PaymentMethod       0
# PaperlessBilling    0
# AverageUsage        0
# TotalUsage          0
# Churn               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['CustomerID', 'Tenure', 'MonthlyCharge', 'TotalCharges', 'Contract',
#        'PaymentMethod', 'PaperlessBilling', 'AverageUsage', 'TotalUsage',
#        'Churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# CustomerID           object
# Tenure                int64
# MonthlyCharge       float64
# TotalCharges        float64
# Contract             object
# PaymentMethod        object
# PaperlessBilling      int64
# AverageUsage        float64
# TotalUsage          float64
# Churn                 int64
# dtype: object

# %%
data=data.drop(columns=['MonthlyCharge','TotalUsage','CustomerID'], axis=1 )
data.head()
# Out:
#    Tenure  TotalCharges        Contract     PaymentMethod  PaperlessBilling  \
# 0      38   4885.671652  Month-to-month       Credit card                 0
# 1      44   5407.790597        One year     Bank transfer                 0
# 2      13   1028.654035  Month-to-month       Credit card                 0
# 3       9    796.835005  Month-to-month  Electronic check                 0
# 4      10   1481.000003        One year  Electronic check                 1
#
#    AverageUsage  Churn
# 0     34.577658      0
# 1     43.387375      0
# 2     14.974818      0
# 3     14.611459      1
# 4     15.346697      0

# %%
data['Churn']=data['Churn'].astype(int)
data=pd.get_dummies(data,columns=['Contract','PaymentMethod'], drop_first=True)

# %%
x=data.drop('Churn',axis=1)
y=data['Churn']

# %%
data.shape
# Out:
# (10000, 10)

# %%
data.shape
# Out:
# (10000, 10)

# %%
x.shape
# Out:
# (10000, 9)

# %%
y.shape
# Out:
# (10000,)

# %%
#https://www.kaggle.com/datasets/rajagrawal7089/customer-churn

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
data.head()
# Out:
#    Tenure  TotalCharges  PaperlessBilling  AverageUsage  Churn  \
# 0      38   4885.671652                 0     34.577658      0
# 1      44   5407.790597                 0     43.387375      0
# 2      13   1028.654035                 0     14.974818      0
# 3       9    796.835005                 0     14.611459      1
# 4      10   1481.000003                 1     15.346697      0
#
#    Contract_One year  Contract_Two year  PaymentMethod_Credit card  \
# 0              False              False                       True
# 1               True              False                      False
# 2              False              False                       True
# 3              False              False                      False
# 4               True              False                      False
#
#    PaymentMethod_Electronic check  PaymentMethod_Mailed check
# 0                           False                       False
# ...

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_predict)
precision=precision_score(y_test,y_predict,average="macro")
recall=recall_score(y_test,y_predict,average="macro")
f1=f1_score(y_test,y_predict,average="macro")
cm=confusion_matrix(y_test,y_predict)
print('Accuracy:',accuracy)
print('Precision:',precision)
print('Recall:',recall)
print('F1 Score:',f1)
print('Confusion Matrix:\n',cm)
# Out:
# Accuracy: 0.749
# Precision: 0.3745
# Recall: 0.5
# F1 Score: 0.4282447112635792
# Confusion Matrix:
#  [[1498    0]
#  [ 502    0]]
